# %%
import os
os.chdir("/Users/nicorod/Documents/repos/Chatbot-Fonasa")

# %%
print(os.getcwd())
# Out:
# /Users/nicorod/Documents/repos/Chatbot-Fonasa

# %%
from web_scraping.scraper import save_url_content
from web_scraping.pdf_transform import process_folder

# %% [markdown]
# ## FONASA's URLs
#
# 1. La información relacionada a FONASA proviene de dos fuentes: Superintendencia de SALUD, y la página web de FONASA
# 2. Toda la información se va a guardar raw diferenciando el origen

# %%
# Superintendencia de Salud
urls_faqs_supersalud_materia_fonasa = [
    {
        "name": "Cobertura y Bonificaciones FONASA",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3459.html",
    },
    {
        "name": "Cotizaciones de Salud FONASA",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3458.html",
    },
    {
        "name": "Afiliacion y desafiliacion FONASA",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3457.html",
    },
    {
        "name": "Seguro catastrófico",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-4010.html",
    },
    {
        "name": "Garantías explícitas en Salud GES",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3460.html",
    },
    {
        "name": "Licencias Médicas y Subsidios por Incapacidad Laboral",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3461.html",
    },
    {
        "name": "Ley Ricarte Soto",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-7142.html",
    },
    {
        "name": "Beneficiarios Fonasa",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-6058.html",
    }
]

urls_faqs_supersalud_materia_isapres = [
    {
        "name": "Alzas de precio base de las Isapres",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-5014.html",
    },
    {
        "name": "Contrato de Salud",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3464.html",
    },
    {
        "name": "Cobertura y Bonificaciones",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3466.html",
    },
    {
        "name": "Cobertura Adicional para Enfermedades Catastróficas (CAEC)",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-4011.html",
    },
    {
        "name": "Cotizaciones de salud",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3465.html",
    },
    {
        "name": "Excedentes de cotización",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-7345.html",
    },
    {
        "name": "Garantías explícitas en Salud GES",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3467.html",
    },
    {
        "name": "Ley Ricarte Soto",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-7143.html",
    },
    {
        "name": "Licencias Médicas y Subsidios por Incapacidad Laboral",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3468.html",
    },
]

urls_faqs_supersalud_materia_prestadores = [
    {
        "name": "Acreditación de Prestadores",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3473.html",
    },
    {
        "name": "Registros",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3471.html",
    },
    {
        "name": "Mediación con prestadores",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3922.html",
    },
    {
        "name": "Ley de cheque en garantía",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3474.html",
    },
    {
        "name": "Ley de derechos y deberes",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-4185.html",
    },
]

urls_faqs_supersalud_personas = [
    {
        "name": "Beneficiarios Fonasa",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-6058.html",
    },
    {
        "name": "Beneficiarios Isapres",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-6059.html",
    },
]

urls_faqs_supersalud_prestadores = [
    {
        "name": "Prestadores Individuales",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-6054.html",
    },
    {
        "name": "Prestadores institucionales",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-6055.html",
    },
    {
        "name": "Entidades Certificadoras",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-6057.html",
    },
]

# FONASA 
urls_fonasa = [
    {
        "name": "Conoce todos nuestros trámites - beneficiario",
        "url": "https://www.fonasa.cl/sites/fonasa/tramites#beneficiarios",
        "folder": "tramites",
    },
    {
        "name": "Conoce todos nuestros trámites - prestadores",
        "url": "https://www.fonasa.cl/sites/fonasa/tramites#prestadores",
        "folder": "tramites",
    },
    {
        "name": "Conoce todos nuestros trámites - empleadores",
        "url": "https://www.fonasa.cl/sites/fonasa/tramites#empleadores",
        "folder": "tramites",
    },
    {
        "name": "Beneficios y Coberturas - plan de salud",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/plan-salud#plan-de-salud",
        "folder": "beneficios",
    },
    {
        "name": "Beneficios y Coberturas - consultas medicas",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/plan-salud#consultas-mdicas",
        "folder": "beneficios",
    },
    {
        "name": "Beneficios y Coberturas - examenes",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/plan-salud#exmenes",
        "folder": "beneficios",
    },
    {
        "name": "Beneficios y Coberturas - procedimiento diagnosticos",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/plan-salud#procedimientos-diagnsticos",
        "folder": "beneficios",
    },
    {
        "name": "Beneficios y Coberturas - procedimientos terapeuticos",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/plan-salud#procedimientos-teraputicos",
        "folder": "beneficios",
    },
    {
        "name": "Beneficios y Coberturas - cirugias",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/plan-salud#cirugas",
        "folder": "beneficios",
    },
    {
        "name": "Beneficios y Coberturas - rehabilitacion",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/plan-salud#rehabilitacin",
        "folder": "beneficios",
    },
    {
        "name": "Beneficios y Coberturas - salud bucal",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/plan-salud#salud-bucal",
        "folder": "beneficios",
    },
    {
        "name": "Beneficios y Coberturas - salud mental",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/plan-salud#salud-mental",
        "folder": "beneficios",
    },
    {
        "name": "Beneficios y Coberturas - examen de medicina preventiva",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/plan-salud#examen-de-medicina-preventiva",
        "folder": "beneficios",
    },
    {
        "name": "Programas Especiales - en que consiste",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/programas-especiales#en-qu-consiste-",
        "folder": "programas_especiales",
    },
    {
        "name": "Programas Especiales - fertilizacion asistida",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/programas-especiales#fertilizacin-asistida",
        "folder": "programas_especiales",
    },
    {
        "name": "Programas Especiales - programa de transplantes",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/programas-especiales#programa-de-trasplantes",
        "folder": "programas_especiales",
    },
    {
        "name": "Programas Especiales - programa de cirugia baritrica",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/programas-especiales#programa-de-ciruga-baritrica",
        "folder": "programas_especiales",
    },
    {
        "name": "Programas Especiales - programa ELEAM ",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/programas-especiales#programa-eleam",
        "folder": "programas_especiales",
    },
    {
        "name": "Afiliacion Fonasa - en que consiste",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/afiliate-fonasa#en-qu-consiste-",
        "folder": "afiliacion_fonasa",
    },
    {
        "name": "Afiliacion Fonasa - paso a paso",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/afiliate-fonasa#paso-a-paso",
        "folder": "afiliacion_fonasa",
    },
    {
        "name": "Afiliacion Fonasa - importante",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/afiliate-fonasa#importante",
        "folder": "afiliacion_fonasa",
    },
    {
        "name": "Afiliacion Fonasa - para quienes",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/afiliate-fonasa#para-quines-",
        "folder": "afiliacion_fonasa",
    },
    {
        "name": "Afiliacion Fonasa - cargas legales",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/afiliate-fonasa#cargas-legales",
        "folder": "afiliacion_fonasa",
    },
    {
        "name": "Afiliacion Fonasa - que cubre",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/afiliate-fonasa#qu-cubre-",
        "folder": "afiliacion_fonasa",
    },
    {
        "name": "Afiliacion Fonasa - casos especiales",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/afiliate-fonasa#casos-especiales",
        "folder": "afiliacion_fonasa",
    },
    {
        "name": "Afiliacion Fonasa - requisitos",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/afiliate-fonasa#requisitos",
        "folder": "afiliacion_fonasa",
    },
    {
        "name": "Afiliacion Fonasa - desafiliacion",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/afiliate-fonasa#desafiliacin",
        "folder": "afiliacion_fonasa",
    },
    {
        "name": "Red de Atencion - red publica",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/red-atencion#red-pblica",
        "folder": "red_de_atencion",
    },
    {
        "name": "Red de Atencion - red privada",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/red-atencion#red-privada",
        "folder": "red_de_atencion",
    },
    {
        "name": "Red de Atencion - prestadores en convenio",
        "url": "https://www.fonasa.cl/sites/fonasa/tramites/red-prestadores-convenio",
        "folder": "red_de_atencion",
    },
    {
        "name": "Cotizaciones - que son",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/cotizaciones",
        "folder": "cotizaciones",
    },
    {
        "name": "Descuentos Medicamentos - como acceder",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/medicamentos",
        "folder": "descuentos_medicamentos",
    },
    {
        "name": "tramites - beneficiario",
        "url": "https://www.fonasa.cl/sites/Satellite?c=Page&cid=1496943219722&pagename=Fonasa2019%2FPage%2FF2_Tramites",
        "folder": "cambio_fonasa_isapre",
    },
    {
        "name": "Bonos - que son los bonos",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/bonos",
        "folder": "bonos",
    },
    {
        "name": "Bonos - conoce el valor de tu bono en la MLE",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/tramites/valor-bono",
        "folder": "bonos",
    },
    {
        "name": "Bonos - Que son los bonos PAD",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/bonos-pad",
        "folder": "bonos",
    },
    {
        "name": "Bonos - Ficha prestaciones PAD",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/bonos-pad#revisa-ac-las-fichas-de-prestaciones-pad",
        "folder": "bonos",
    },
    {
        "name": "Bonos - Prestadores Convenios PAD",
        "url": "https://www.fonasa.cl/sites/fonasa/beneficiarios/bonos-pad#busca-aqu-a-los-prestadores-con-convenio-pad",
        "folder": "bonos",
    },
    {
        "name": "tramites - valorizacion programa y ordenes medicas",
        "url": "https://portalserviciosweb.fonasa.cl",
        "folder": "tramites",
    },
    {
        "name": "Bonos - prestaciones PAD",
        "url": "https://www.fonasa.cl/sites/fonasa/coberturas/prestaciones-PAD",
        "folder": "bonos",
    },

]

# %% [markdown]
# ## AI Web Scrapper
# 1. En este caso en específico, solamente vamos a utilizar Jina AI
# 2. Se deja todo en función de lista en caso de que sea necesario hacer un scrapping con otras herramientas
# 3. El output genera una tabla que compara los costos de usar distintas herramientas

# %%
#path_supersalud_meteria_fonasa = "/Users/nicorod/Documents/repos/Chatbot-Fonasa/data/raw/supersalud/meteria_fonasa"
path_data_fonasa = "/Users/nicorod/Documents/repos/Chatbot-Fonasa/data/raw/fonasa"

# %%
all_content = save_url_content(urls_fonasa, path_data_fonasa)

# %% [markdown]
# # Transform to PDF

# %%
input_folder = "data/processed/fonasa"
output_folder = "data/pdf/fonasa"
process_folder(input_folder, output_folder)
# Out:
# Processing files: 100%|██████████| 39/39 [00:00<00:00, 247.54it/s]
