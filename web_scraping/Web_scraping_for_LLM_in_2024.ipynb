# %% [markdown]
# <a href="https://colab.research.google.com/github/trancethehuman/ai-workshop-code/blob/main/Web_scraping_for_LLM_in_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Let's setup our test: Get my competitors' pricing from their websites
#
# This is real. I am doing this not for shits and giggles.
#
# I'm building an interactive learning platform where content is taught using AI. Seems like everyone else is focusing on augmenting the authoring process and not the learning experience, but whatever.

# %%
competitor_sites = [
    {
        "name": "Cobertura y Bonificaciones FONASA",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3459.html"
    },
    {
        "name": "Cotizaciones de Salud FONASA",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3458.html"
    },
    {
        "name": "Afiliacion y desafiliacion FONASA",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3457.html"
    },
    {
        "name": "Seguro catastrófico",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-4010.html"
    },
    {
        "name": "Garantías explícitas en Salud GES",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3460.html"
    },
    {
        "name": "Licencias Médicas y Subsidios por Incapacidad Laboral",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3461.html"
    },
    {
        "name": "Ley Ricarte Soto",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-7142.html"
    },
    {
        "name": "Beneficiarios Fonasa",
        "url": "https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-6058.html"
    }
]

# %% [markdown]
# ### Let's setup cost calculations
#
# So we can compare them side-by-side

# %% [markdown]
# We can calculate how much it'll cost by using OpenAI's `tiktoken` library.
#
# (side note: as of today, OpenAI hasn't updated `tiktoken` with the actual algorithm used to in `gpt-4o`, so we'll guesstimate using `gpt-4` tokenization encoding (cl100k_base).

# %%
pip install tiktoken --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import tiktoken

def count_tokens(input_string: str) -> int:
    tokenizer = tiktoken.get_encoding("cl100k_base")

    tokens = tokenizer.encode(input_string)

    return len(tokens)

def calculate_cost(input_string: str, cost_per_million_tokens: float = 5) -> float:
    num_tokens = count_tokens(input_string)

    total_cost = (num_tokens / 1_000_000) * cost_per_million_tokens

    return total_cost

# Example usage:
input_string = "What's the difference between beer nuts and deer nuts? Beer nuts are about 5 dollars. Deer nuts are just under a buck."
cost = calculate_cost(input_string)
print(f"The total cost for using gpt-4o is: $US {cost:.6f}")
# Out:
# The total cost for using gpt-4o is: $US 0.000135

# %% [markdown]
# ### Additionally, I want to see the test results in a nice table, so let's set that up.

# %%
pip install prettytable tqdm --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from typing import List, Callable, Dict
from prettytable import PrettyTable, ALL
from tqdm import tqdm

def view_scraped_content(
        scrape_url_functions: List[Dict[str, Callable[[str], str]]], 
        sites_list: List[Dict[str, str]], 
        characters_to_display: int = 500, 
        table_max_width: int = 50) -> List[Dict[str, str]]:
    content_table_headers = ["Site Name"] + [f"{func['name']} content" for func in scrape_url_functions]
    cost_table_headers = ["Site Name"] + [f"{func['name']} cost" for func in scrape_url_functions]

    content_table = PrettyTable()
    content_table.field_names = content_table_headers

    cost_table = PrettyTable()
    cost_table.field_names = cost_table_headers

    scraped_data = []

    for site in sites_list:
        content_row = [site['name']]
        cost_row = [site['name']]
        site_data = {"provider": site['name'], "sites": []}

        for scrape_function in scrape_url_functions:
            function_name = scrape_function['name']
            for _ in tqdm([site], desc=f"Processing site {site['name']} using {function_name}"):
                try:
                    content = scrape_function['function'](site['url'])
                    content_snippet = content[:characters_to_display]
                    content_row.append(content_snippet)

                    cost = calculate_cost(content)
                    cost_row.append(f"${cost:.6f}")

                    site_data["sites"].append({"name": function_name, "content": content})
                except Exception as e:
                    error_message = f"Error: {str(e)}"
                    content_row.append(error_message)
                    cost_row.append("Error")

                    site_data["sites"].append({"name": function_name, "content": error_message})
                    continue

        content_table.add_row(content_row)
        cost_table.add_row(cost_row)
        scraped_data.append(site_data)

    content_table.max_width = table_max_width
    content_table.hrules = ALL

    cost_table.max_width = table_max_width
    cost_table.hrules = ALL

    print("Content Table:")
    print(content_table)

    print("\nCost Table:\nThis is how much it would cost to use gpt-4o to parse this content for extraction.")
    print(cost_table)

    return scraped_data

# %% [markdown]
# ## Setup all the scrapers
#
# Let's setup all of our scrapers.

# %% [markdown]
# ### Beautiful Soup

# %%
pip install requests beautifulsoup4 --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Beautiful Soup utility functions

import requests
from bs4 import BeautifulSoup

def beautiful_soup_scrape_url(url: str):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    return str(soup)

# %% [markdown]
# ### Reader API by Jina AI
#
# Let's setup Jina AI's scrape method. This one is dead easy.

# %%
import requests

def scrape_jina_ai(url: str) -> str:
  response = requests.get("https://r.jina.ai/" + url)
  return response.text

# %% [markdown]
# ### Firecrawl from Mendable.

# %%
pip install firecrawl-py --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import firecrawl
import getpass

FIRECRAWL_API_KEY = getpass.getpass("Mendable API Key: ")

def scrape_firecrawl(url: str):
    app = firecrawl.FirecrawlApp(api_key=FIRECRAWL_API_KEY)
    scraped_data = app.scrape_url(url)["markdown"]
    return scraped_data

# %% [markdown]
# ## Let's run all the scrapers and display them in our comparison table

# %%
list_of_scraper_functions = [
      # {"name": "Beautiful Soup", "function": beautiful_soup_scrape_url},
      # {"name": "Firecrawl", "function": scrape_firecrawl},
      {"name": "Jina AI", "function": scrape_jina_ai}
      ]

#all_content = view_scraped_content(list_of_scraper_functions, competitor_sites, 700, 20)

# %%
import os

# %%
def view_scraped_content2(
        scrape_url_functions: List[Dict[str, Callable[[str], str]]], 
        sites_list: List[Dict[str, str]], 
        characters_to_display: int = 500, 
        table_max_width: int = 50) -> List[Dict[str, str]]:
    
    content_table_headers = ["Site Name"] + [f"{func['name']} content" for func in scrape_url_functions]
    cost_table_headers = ["Site Name"] + [f"{func['name']} cost" for func in scrape_url_functions]

    content_table = PrettyTable()
    content_table.field_names = content_table_headers

    cost_table = PrettyTable()
    cost_table.field_names = cost_table_headers

    scraped_data = []

    # Ensure the data/raw directory exists
    raw_data_dir = '/Users/nicorod/Documents/repos/Chatbot-Fonasa/data/raw'
    os.makedirs(raw_data_dir, exist_ok=True)
    if not os.path.exists(raw_data_dir):
        print(f"Directory creation failed: {raw_data_dir}")
        return scraped_data

    for site in sites_list:
        content_row = [site['name']]
        cost_row = [site['name']]
        site_data = {"provider": site['name'], "sites": []}

        for scrape_function in scrape_url_functions:
            function_name = scrape_function['name']
            for _ in tqdm([site], desc=f"Processing site {site['name']} using {function_name}"):
                try:
                    content = scrape_function['function'](site['url'])
                    content_snippet = content[:characters_to_display]
                    content_row.append(content_snippet)

                    cost = calculate_cost(content)
                    cost_row.append(f"${cost:.6f}")

                    site_data["sites"].append({"name": function_name, "content": content})

                    # Save content to a file
                    filename = os.path.join(raw_data_dir, f"{site['name'].replace(' ', '_')}_{function_name}.txt")
                    with open(filename, 'w', encoding='utf-8') as f:
                        f.write(content)
                    if os.path.exists(filename):
                        print(f"Successfully saved content to {filename}")
                    else:
                        print(f"Failed to save content to {filename}")
                except Exception as e:
                    error_message = f"Error: {str(e)}"
                    content_row.append(error_message)
                    cost_row.append("Error")

                    site_data["sites"].append({"name": function_name, "content": error_message})
                    print(f"Failed to process site {site['name']} using {function_name}: {e}")
                    continue

        content_table.add_row(content_row)
        cost_table.add_row(cost_row)
        scraped_data.append(site_data)

    content_table.max_width = table_max_width
    content_table.hrules = ALL

    cost_table.max_width = table_max_width
    cost_table.hrules = ALL

    print("Content Table:")
    print(content_table)

    print("\nCost Table:\nThis is how much it would cost to use GPT-4 to parse this content for extraction.")
    print(cost_table)

    return scraped_data

# %%
all_content = view_scraped_content2(list_of_scraper_functions, competitor_sites, 700, 20)
# Out:
# Processing site Cobertura y Bonificaciones FONASA using Jina AI: 100%|██████████| 1/1 [00:00<00:00,  2.35it/s]
# Successfully saved content to /Users/nicorod/Documents/repos/Chatbot-Fonasa/data/raw/Cobertura_y_Bonificaciones_FONASA_Jina AI.txt
# Processing site Cotizaciones de Salud FONASA using Jina AI: 100%|██████████| 1/1 [00:00<00:00,  1.76it/s]
# Successfully saved content to /Users/nicorod/Documents/repos/Chatbot-Fonasa/data/raw/Cotizaciones_de_Salud_FONASA_Jina AI.txt
# Processing site Afiliacion y desafiliacion FONASA using Jina AI: 100%|██████████| 1/1 [00:00<00:00,  1.97it/s]
# Successfully saved content to /Users/nicorod/Documents/repos/Chatbot-Fonasa/data/raw/Afiliacion_y_desafiliacion_FONASA_Jina AI.txt
# Processing site Seguro catastrófico using Jina AI: 100%|██████████| 1/1 [00:00<00:00,  1.98it/s]
# Successfully saved content to /Users/nicorod/Documents/repos/Chatbot-Fonasa/data/raw/Seguro_catastrófico_Jina AI.txt
# Processing site Garantías explícitas en Salud GES using Jina AI: 100%|██████████| 1/1 [00:00<00:00,  2.47it/s]
# Successfully saved content to /Users/nicorod/Documents/repos/Chatbot-Fonasa/data/raw/Garantías_explícitas_en_Salud_GES_Jina AI.txt
# Processing site Licencias Médicas y Subsidios por Incapacidad Laboral using Jina AI: 100%|██████████| 1/1 [00:00<00:00,  1.20it/s]
# Successfully saved content to /Users/nicorod/Documents/repos/Chatbot-Fonasa/data/raw/Licencias_Médicas_y_Subsidios_por_Incapacidad_Laboral_Jina AI.txt
# Processing site Ley Ricarte Soto using Jina AI: 100%|██████████| 1/1 [00:00<00:00,  1.68it/s]
# Successfully saved content to /Users/nicorod/Documents/repos/Chatbot-Fonasa/data/raw/Ley_Ricarte_Soto_Jina AI.txt
# Processing site Beneficiarios Fonasa using Jina AI: 100%|██████████| 1/1 [00:00<00:00,  1.75it/s]
# Successfully saved content to /Users/nicorod/Documents/repos/Chatbot-Fonasa/data/raw/Beneficiarios_Fonasa_Jina AI.txt
# Content Table:
# +----------------------+----------------------+
# |      Site Name       |   Jina AI content    |
# +----------------------+----------------------+
# |     Cobertura y      |  Title: Cobertura y  |
# |    Bonificaciones    |    Bonificaciones    |
# |        FONASA        |                      |
# |                      | URL Source: https:// |
# |                      | www.superdesalud.gob |
# |                      | .cl/consultas/667/w3 |
# |                      |   -propertyvalue-    |
# |                      |      3459.html       |
# |                      |                      |
# |                      |  Markdown Content:   |
# |                      |  #### [¿A partir de  |
# |                      |      cuándo los      |
# |                      |  beneficiarios del   |
# |                      |    Fonasa pueden     |
# |                      | comprar bonos?abrir  |
# |                      | cerrar](https://www. |
# |                      | superdesalud.gob.cl/ |
# |                      |  consultas/667/w3-   |
# |                      |    propertyvalue-    |
# |                      | 3459.html#recuadros_ |
# |                      | articulo_5078_0 "Los |
# |                      | afiliados de Fonasa  |
# |                      | y sus cargas pueden  |
# |                      |  comprar bonos, una  |
# |                      | vez que cumplan con  |
# |                      |  los requisitos de   |
# |                      | pago de cotizaciones |
# |                      |   según la calidad   |
# |                      |      laboral o       |
# |                      |   previsional del    |
# |                      |     cotizante.")     |
# |                      |                      |
# |                      |   Los afiliados de   |
# |                      | Fonasa y sus cargas  |
# |                      |    pueden comprar    |
# |                      |  bonos, una vez que  |
# |                      |   cumplan con los    |
# |                      |  requisitos de pago  |
# |                      |   de cotizaciones    |
# |                      |   según la calidad   |
# |                      |      laboral o       |
# |                      |   previsional del    |
# |                      |      cotizante.      |
# |                      |                      |
# |                      |   Los bonos de Fo    |
# +----------------------+----------------------+
# |   Cotizaciones de    | Title: Cotizaciones  |
# |     Salud FONASA     |       de Salud       |
# |                      |                      |
# |                      | URL Source: https:// |
# |                      | www.superdesalud.gob |
# |                      | .cl/consultas/667/w3 |
# |                      |   -propertyvalue-    |
# |                      |      3458.html       |
# |                      |                      |
# |                      |  Markdown Content:   |
# |                      |   Cotizaciones de    |
# |                      |  Salud - Preguntas   |
# |                      |     Frecuentes.      |
# |                      | Superintendencia de  |
# |                      |  Salud, Gobierno de  |
# |                      |        Chile.        |
# |                      |   ===============    |
# |                      |      [Contenido prin |
# |                      | cipal](https://www.s |
# |                      | uperdesalud.gob.cl/c |
# |                      |   onsultas/667/w3-   |
# |                      |    propertyvalue-    |
# |                      | 3458.html#contents)  |
# |                      |                      |
# |                      |  Toggle navigation   |
# |                      | [Superintendencia de |
# |                      | Salud - Gobierno de  |
# |                      | Chile](https://www.s |
# |                      | uperdesalud.gob.cl/6 |
# |                      |  64/w3-channel.html  |
# |                      | "Logo oficial de la  |
# |                      | Superintendencia de  |
# |                      |  Salud del Gobierno  |
# |                      |      de Chile")      |
# |                      |                      |
# |                      | *   [Inicio](https:/ |
# |                      | /www.superdesalud.go |
# |                      |     b.cl/664/w3-     |
# |                      | channel.html "Ir al  |
# |                      |       inicio")       |
# |                      | *   [Atención Person |
# |                      | as](https://www.supe |
# |                      | rdesalud.gob.cl/cons |
# |                      |  ultas/667/w3-prop   |
# +----------------------+----------------------+
# |     Afiliacion y     | Title: Afiliación y  |
# | desafiliacion FONASA |    Desafiliación     |
# |                      |                      |
# |                      | URL Source: https:// |
# |                      | www.superdesalud.gob |
# |                      | .cl/consultas/667/w3 |
# |                      |   -propertyvalue-    |
# |                      |      3457.html       |
# |                      |                      |
# |                      |  Markdown Content:   |
# |                      |     Afiliación y     |
# |                      |   Desafiliación -    |
# |                      |      Preguntas       |
# |                      |     Frecuentes.      |
# |                      | Superintendencia de  |
# |                      |  Salud, Gobierno de  |
# |                      |        Chile.        |
# |                      |   ===============    |
# |                      |      [Contenido prin |
# |                      | cipal](https://www.s |
# |                      | uperdesalud.gob.cl/c |
# |                      |   onsultas/667/w3-   |
# |                      |    propertyvalue-    |
# |                      | 3457.html#contents)  |
# |                      |                      |
# |                      |  Toggle navigation   |
# |                      | [Superintendencia de |
# |                      | Salud - Gobierno de  |
# |                      | Chile](https://www.s |
# |                      | uperdesalud.gob.cl/6 |
# |                      |  64/w3-channel.html  |
# |                      | "Logo oficial de la  |
# |                      | Superintendencia de  |
# |                      |  Salud del Gobierno  |
# |                      |      de Chile")      |
# |                      |                      |
# |                      | *   [Inicio](https:/ |
# |                      | /www.superdesalud.go |
# |                      |     b.cl/664/w3-     |
# |                      | channel.html "Ir al  |
# |                      |       inicio")       |
# |                      | *   [Atención Person |
# |                      | as](https://www.supe |
# |                      | rdesalud.gob.cl/cons |
# |                      |       ultas/6        |
# +----------------------+----------------------+
# | Seguro catastrófico  |    Title: Seguro     |
# |                      |     catastrófico     |
# |                      |                      |
# |                      | URL Source: https:// |
# |                      | www.superdesalud.gob |
# |                      | .cl/consultas/667/w3 |
# |                      |   -propertyvalue-    |
# |                      |      4010.html       |
# |                      |                      |
# |                      |  Markdown Content:   |
# |                      | Seguro catastrófico  |
# |                      |     - Preguntas      |
# |                      |     Frecuentes.      |
# |                      | Superintendencia de  |
# |                      |  Salud, Gobierno de  |
# |                      |        Chile.        |
# |                      |   ===============    |
# |                      |      [Contenido prin |
# |                      | cipal](https://www.s |
# |                      | uperdesalud.gob.cl/c |
# |                      |   onsultas/667/w3-   |
# |                      |    propertyvalue-    |
# |                      | 4010.html#contents)  |
# |                      |                      |
# |                      |  Toggle navigation   |
# |                      | [Superintendencia de |
# |                      | Salud - Gobierno de  |
# |                      | Chile](https://www.s |
# |                      | uperdesalud.gob.cl/6 |
# |                      |  64/w3-channel.html  |
# |                      | "Logo oficial de la  |
# |                      | Superintendencia de  |
# |                      |  Salud del Gobierno  |
# |                      |      de Chile")      |
# |                      |                      |
# |                      | *   [Inicio](https:/ |
# |                      | /www.superdesalud.go |
# |                      |     b.cl/664/w3-     |
# |                      | channel.html "Ir al  |
# |                      |       inicio")       |
# |                      | *   [Atención Person |
# |                      | as](https://www.supe |
# |                      | rdesalud.gob.cl/cons |
# |                      |    ultas/667/w3-     |
# |                      |       property       |
# +----------------------+----------------------+
# | Garantías explícitas |   Title: Garantías   |
# |     en Salud GES     | explícitas en Salud  |
# |                      |         GES          |
# |                      |                      |
# |                      | URL Source: https:// |
# |                      | www.superdesalud.gob |
# |                      | .cl/consultas/667/w3 |
# |                      |   -propertyvalue-    |
# |                      |      3460.html       |
# |                      |                      |
# |                      |  Markdown Content:   |
# |                      |   #### [¿Qué deben   |
# |                      |      saber los       |
# |                      |    profesionales     |
# |                      |  especialistas que   |
# |                      |    obtuvieron la     |
# |                      |   Certificación de   |
# |                      |    Especialidades    |
# |                      |    Médicas en el     |
# |                      | extranjero?abrir cer |
# |                      | rar](https://www.sup |
# |                      | erdesalud.gob.cl/con |
# |                      |    sultas/667/w3-    |
# |                      |    propertyvalue-    |
# |                      | 3460.html#recuadros_ |
# |                      | articulo_5078_1 "En  |
# |                      |  enero de 2017 fue   |
# |                      |   publicada en el    |
# |                      |  Diario Oficial la   |
# |                      |  Ley N°20.985, que   |
# |                      |   establece normas   |
# |                      | sobre certificación  |
# |                      |  de especialidades   |
# |                      | médicas obtenidas en |
# |                      |  el extranjero. Acá  |
# |                      |    destacamos sus    |
# |                      |     aspectos más     |
# |                      |   relevantes para    |
# |                      |    orientar a los    |
# |                      |    profesionales     |
# |                      |    interesados.")    |
# |                      |                      |
# |                      | En enero de 2017 fue |
# |                      |   publicada en el    |
# |                      |   Diario Oficial l   |
# +----------------------+----------------------+
# | Licencias Médicas y  |   Title: Licencias   |
# |    Subsidios por     | Médicas y Subsidios  |
# | Incapacidad Laboral  |   por Incapacidad    |
# |                      |       Laboral        |
# |                      |                      |
# |                      | URL Source: https:// |
# |                      | www.superdesalud.gob |
# |                      | .cl/consultas/667/w3 |
# |                      |   -propertyvalue-    |
# |                      |      3461.html       |
# |                      |                      |
# |                      |  Markdown Content:   |
# |                      |  #### [¿La Isapre o  |
# |                      |   la COMPIN pueden   |
# |                      |  rechazar o reducir  |
# |                      | una licencia médica, |
# |                      |  cuáles serían las   |
# |                      |    causales de la    |
# |                      | misma?abrir cerrar]( |
# |                      | https://www.superdes |
# |                      | alud.gob.cl/consulta |
# |                      |      s/667/w3-       |
# |                      |    propertyvalue-    |
# |                      | 3461.html#recuadros_ |
# |                      | articulo_5078_0 "Sí, |
# |                      |    la Isapre y la    |
# |                      |    COMPIN pueden     |
# |                      | rechazar, reducir o  |
# |                      |  ampliar el periodo  |
# |                      |   de reposo de una   |
# |                      | licencia médica. Las |
# |                      | causales de rechazo  |
# |                      |  o reducción de una  |
# |                      |   licencia médica    |
# |                      | pueden ser de orden  |
# |                      |  médico, jurídico y  |
# |                      |  administrativo.")   |
# |                      |                      |
# |                      |  Sí, la Isapre y la  |
# |                      |    COMPIN pueden     |
# |                      | rechazar, reducir o  |
# |                      |  ampliar el periodo  |
# |                      |      de reposo       |
# +----------------------+----------------------+
# |   Ley Ricarte Soto   |  Title: Ley Ricarte  |
# |                      |         Soto         |
# |                      |                      |
# |                      | URL Source: https:// |
# |                      | www.superdesalud.gob |
# |                      | .cl/consultas/667/w3 |
# |                      |   -propertyvalue-    |
# |                      |      7142.html       |
# |                      |                      |
# |                      |  Markdown Content:   |
# |                      | #### [¿Qué es la Ley |
# |                      |     Ricarte Soto     |
# |                      | (20.850)?abrir cerra |
# |                      | r](https://www.super |
# |                      | desalud.gob.cl/consu |
# |                      |     ltas/667/w3-     |
# |                      |    propertyvalue-    |
# |                      | 7142.html#recuadros_ |
# |                      | articulo_5078_0 "La  |
# |                      |  Ley Nº 20.850 creó  |
# |                      |    un Sistema de     |
# |                      |      Protección      |
# |                      |   Financiera para    |
# |                      |    Diagnósticos y    |
# |                      | Tratamientos de Alto |
# |                      |  Costo, de carácter  |
# |                      |  universal, que es   |
# |                      |   asegurado por el   |
# |                      |  FONASA a todos los  |
# |                      | beneficiarios de los |
# |                      |       sistemas       |
# |                      |   previsionales de   |
# |                      | salud de Chile. Esto |
# |                      | es, isapres, Fonasa  |
# |                      | y las Instituciones  |
# |                      | de Salud Previsional |
# |                      |    de las Fuerzas    |
# |                      | Armadas y de Orden y |
# |                      |     de Seguridad     |
# |                      |    Pública.   ")     |
# |                      |                      |
# |                      |   La Ley Nº 20.850   |
# |                      |  creó un Sistema de  |
# |                      |    Protección Fi     |
# +----------------------+----------------------+
# | Beneficiarios Fonasa | Title: Beneficiarios |
# |                      |        Fonasa        |
# |                      |                      |
# |                      | URL Source: https:// |
# |                      | www.superdesalud.gob |
# |                      | .cl/consultas/667/w3 |
# |                      |   -propertyvalue-    |
# |                      |      6058.html       |
# |                      |                      |
# |                      |  Markdown Content:   |
# |                      |    #### [¿En qué     |
# |                      |   consiste la ley    |
# |                      |    N°20.394 sobre    |
# |                      |   prohibición del    |
# |                      | cheque en garantía,  |
# |                      |      cuándo fue      |
# |                      | promulgada y cuáles  |
# |                      |       son sus        |
# |                      | alcances?abrir cerra |
# |                      | r](https://www.super |
# |                      | desalud.gob.cl/consu |
# |                      |     ltas/667/w3-     |
# |                      |    propertyvalue-    |
# |                      | 6058.html#recuadros_ |
# |                      | articulo_5078_0 "La  |
# |                      |    ley N°20.394,     |
# |                      | prohíbe condicionar  |
# |                      |    las atenciones    |
# |                      | médicas a un cheque  |
# |                      |     o dinero en      |
# |                      |     garantía. La     |
# |                      |   referida ley fue   |
# |                      | promulgada con fecha |
# |                      |  3 de noviembre de   |
# |                      | 2009, su publicación |
# |                      | en el diario oficial |
# |                      |    e inicio de su    |
# |                      | vigencia fue el día  |
# |                      |  20 de noviembre de  |
# |                      |       2009. ")       |
# |                      |                      |
# |                      |   La ley N°20.394,   |
# |                      | prohíbe condicionar  |
# |                      |    las atenciones    |
# |                      |     médicas a un     |
# +----------------------+----------------------+
#
# Cost Table:
# This is how much it would cost to use GPT-4 to parse this content for extraction.
# +----------------------+--------------+
# |      Site Name       | Jina AI cost |
# +----------------------+--------------+
# |     Cobertura y      |  $0.021505   |
# |    Bonificaciones    |              |
# |        FONASA        |              |
# +----------------------+--------------+
# |   Cotizaciones de    |  $0.023135   |
# |     Salud FONASA     |              |
# +----------------------+--------------+
# |     Afiliacion y     |  $0.040025   |
# | desafiliacion FONASA |              |
# +----------------------+--------------+
# | Seguro catastrófico  |  $0.020195   |
# +----------------------+--------------+
# | Garantías explícitas |  $0.007510   |
# |     en Salud GES     |              |
# +----------------------+--------------+
# | Licencias Médicas y  |  $0.013435   |
# |    Subsidios por     |              |
# | Incapacidad Laboral  |              |
# +----------------------+--------------+
# |   Ley Ricarte Soto   |  $0.010305   |
# +----------------------+--------------+
# | Beneficiarios Fonasa |  $0.125050   |
# +----------------------+--------------+

# %%
all_content
# Out:
# [{'provider': 'Cobertura y Bonificaciones FONASA',
#   'sites': [{'name': 'Jina AI',
#     'content': 'Title: Cobertura y Bonificaciones\n\nURL Source: https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3459.html\n\nMarkdown Content:\n#### [¿A partir de cuándo los beneficiarios del Fonasa pueden comprar bonos?abrir cerrar](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3459.html#recuadros_articulo_5078_0 "Los afiliados de Fonasa y sus cargas pueden comprar bonos, una vez que cumplan con los requisitos de pago de cotizaciones según la calidad laboral o previsional del cotizante.")\n\nLos afiliados de Fonasa y sus cargas pueden comprar bonos, una vez que cumplan con los requisitos de pago de cotizaciones según la calidad laboral o previsional del cotizante.\n\nLos bonos de Fonasa permiten acceder a una consulta o procedimiento médico con un prestador que se encuentre en convenio, a través de libre elección.\n\nFonasa cuenta con cuatro tipos de bonos para que te atiendas con el profesional de la salud que necesites:\n\n**Bono electrónico:** puedes comprar este bono directamente en el prestador en convenio con Fonasa, a través del sistema Imed y/o Medipass con tu huella dactilar.\n\n**Bono web:** puedes comprar este bono de forma digital en "Mi Fonasa" para consultas de médicos en convenio. Recibirás un correo electrónico y un mensaje de texto con tu bono para que acudas directamente al prestador.\n\n**Prefolio:** es un código que generas en Mi Fonasa o en el call center, que te permite pagar el bono consulta en Sencillito o o Klap (ex Multicaja). Recibirás un voucher, que corresponde al bono, que debes presentar en el prestador el día de tu cita.\n\n**Bono papel:** puedes comprarlo en las sucursales de Fonasa, ChileAtiende y algunos hospitales, clínicas y municipalidades.\n\n#### [¿Cómo acceden los beneficiarios del Fonasa a las atenciones de salud?abrir cerrar](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3459.html#recuadros_articulo_5078_1 "Los beneficiarios del Fonasa acceden a las atenciones de salud a través de 2 (dos) modalidades de atención: Modalidad de Atención Institucional y Modalidad de Libre Elección. ")\n\nLos beneficiarios del Fonasa acceden a las atenciones de salud a través de 2 (dos) modalidades de atención: Modalidad de Atención Institucional y Modalidad de Libre Elección.\n\nEl valor que pagará un beneficiario del Fonasa por la atención otorgada, dependerá de la modalidad de atención que utilice.\n\n*   Si utiliza la **Modalidad de Atención Institucional**, el pago que deberá efectuar dependerá del grupo de ingreso en el cual se encuentre clasificado (grupos B, C o D). El valor de la atención en consultorios de atención primaria es gratuita.\n*   Si utiliza la **Modalidad de Libre Elección**, el valor de la atención dependerá del nivel de inscripción del profesional o institución de salud en convenio con Fonasa.\n\n#### [¿Cómo acceden los cotizantes y beneficiarios del Fonasa al Pago Asociado a Diagnóstico (PAD)?abrir cerrar](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3459.html#recuadros_articulo_5078_2 "El cotizante y beneficiarios del Fonasa acceden al beneficio PAD, a través de un convenio vigente con el Fondo Nacional de Salud (Fonasa) suscrito por los prestadores de salud que cumplen con los requisitos técnicos y de calidad para su realización.")\n\nEl cotizante y beneficiarios del Fonasa acceden al beneficio PAD, a través de un convenio vigente con el Fondo Nacional de Salud (Fonasa) suscrito por los prestadores de salud que cumplen con los requisitos técnicos y de calidad para su realización.\n\nEl PAD (Pago Asociado a Diagnóstico), es una forma de pago que le permite al cotizante y/o beneficiario del Fondo Nacional de Salud (Fonasa) conocer por anticipado el valor total de la cuenta en aquellas intervenciones quirúrgicas inscritas en los establecimientos de salud que tienen convenio con Fonasa.\n\nEl prestador, deberá informar de manera completa y detallada al cotizante y/o beneficiario acerca de las condiciones de la hosp ...
#  {'provider': 'Cotizaciones de Salud FONASA',
#   'sites': [{'name': 'Jina AI',
#     'content': 'Title: Cotizaciones de Salud\n\nURL Source: https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3458.html\n\nMarkdown Content:\nCotizaciones de Salud - Preguntas Frecuentes. Superintendencia de Salud, Gobierno de Chile.\n===============\n     [Contenido principal](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3458.html#contents)\n\nToggle navigation [Superintendencia de Salud - Gobierno de Chile](https://www.superdesalud.gob.cl/664/w3-channel.html "Logo oficial de la Superintendencia de Salud del Gobierno de Chile")\n\n*   [Inicio](https://www.superdesalud.gob.cl/664/w3-channel.html "Ir al inicio")\n*   [Atención Personas](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3458.html#)\n    *   [Beneficiarios Fonasa](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6058.html)\n    *   [Beneficiarios Isapres](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6059.html)\n*   [Atención Prestadores](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3458.html#)\n    *   [Entidades acreditadoras](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6056.html)\n    *   [Entidades certificadoras](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6057.html)\n    *   [Prestadores individuales](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6054.html)\n    *   [Prestadores institucionales](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6055.html)\n*   [Más de Supersalud](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3458.html#)\n    *   [Acerca de la Superintendencia](https://www.superdesalud.gob.cl/664/w3-propertyname-693.html)\n    *   [Regulación](https://www.superdesalud.gob.cl/normativa/668/w3-channel.html)\n    *   [Fiscalización](https://www.superdesalud.gob.cl/664/w3-propertyname-582.html)\n    *   [Sala de prensa](https://www.superdesalud.gob.cl/prensa/672/w3-channel.html)\n    *   [Orientación en salud](https://www.superdesalud.gob.cl/difusion/665/w3-channel.html)\n    *   [Trámites y servicios](https://www.superdesalud.gob.cl/servicios/669/w3-channel.html)\n    *   [Registros](https://www.superdesalud.gob.cl/acreditacion/673/w3-channel.html)\n    *   [Participación Ciudadana](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6141.html)\n    *   [Biblioteca digital](https://www.superdesalud.gob.cl/documentacion/666/w3-channel.html)\n    *   [Observatorio de Calidad en Salud](https://www.superdesalud.gob.cl/observatorio/671/w3-channel.html)\n    *   [Extranet Fonasa, Isapres, FFAA y de Orden y Seguridad](https://www.superdesalud.gob.cl/servicios/669/w3-article-6038.html)\n*   [Contáctanos](https://www.superdesalud.gob.cl/664/w3-propertyvalue-794.html)\n*   [Facebook](https://www.facebook.com/Superintendencia-de-Salud-113210788736738/?ref=ts "Síganos en Facebook")\n*   [Facebook](https://twitter.com/SuperDeSalud)\n*   [Instagram](https://www.instagram.com/superdesaludchile/)\n*   [App Superintendencia de Salud para Adroid](https://play.google.com/store/apps/details?id=cl.dev.superintendecia_app)\n*   [Buscar](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3458.html#tr_buscador)\n    \n    Buscador general Buscar Botón de búsqueda\n    \n     buscar\n    \n\n[Inicio](https://www.superdesalud.gob.cl/664/w3-channel.html) / [Preguntas frecuentes](https://www.superdesalud.gob.cl/consultas/667/w3-channel.html) / [Materias FONASA](https://www.superdesalud.gob.cl/consultas/667/w3-propertyname-594.html) / [Cotizaciones de Salud](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3458.html)\n\nCotizaciones de Salud\n=====================\n\nCompartiricono\n\n[![Image 1: Compartir en Facebook](https://www.superdesalud.gob.cl/consultas/667/channels-18_sociable_sprite_mask.gif)](http://www.facebook.com/share.php?u=http%3A%2F%2Fwww.supersalud.gob.cl%2Fconsultas%2F667%2Fw3-propertyvalue-3458.html&t=Cotizaciones%20de%20Salud%20-%20Preguntas%20Frecuentes.%20Superintendencia%20de%20Salud%2C%20Gobierno%20de%20Chi ...
#  {'provider': 'Afiliacion y desafiliacion FONASA',
#   'sites': [{'name': 'Jina AI',
#     'content': 'Title: Afiliación y Desafiliación\n\nURL Source: https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3457.html\n\nMarkdown Content:\nAfiliación y Desafiliación - Preguntas Frecuentes. Superintendencia de Salud, Gobierno de Chile.\n===============\n     [Contenido principal](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3457.html#contents)\n\nToggle navigation [Superintendencia de Salud - Gobierno de Chile](https://www.superdesalud.gob.cl/664/w3-channel.html "Logo oficial de la Superintendencia de Salud del Gobierno de Chile")\n\n*   [Inicio](https://www.superdesalud.gob.cl/664/w3-channel.html "Ir al inicio")\n*   [Atención Personas](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3457.html#)\n    *   [Beneficiarios Fonasa](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6058.html)\n    *   [Beneficiarios Isapres](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6059.html)\n*   [Atención Prestadores](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3457.html#)\n    *   [Entidades acreditadoras](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6056.html)\n    *   [Entidades certificadoras](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6057.html)\n    *   [Prestadores individuales](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6054.html)\n    *   [Prestadores institucionales](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6055.html)\n*   [Más de Supersalud](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3457.html#)\n    *   [Acerca de la Superintendencia](https://www.superdesalud.gob.cl/664/w3-propertyname-693.html)\n    *   [Regulación](https://www.superdesalud.gob.cl/normativa/668/w3-channel.html)\n    *   [Fiscalización](https://www.superdesalud.gob.cl/664/w3-propertyname-582.html)\n    *   [Sala de prensa](https://www.superdesalud.gob.cl/prensa/672/w3-channel.html)\n    *   [Orientación en salud](https://www.superdesalud.gob.cl/difusion/665/w3-channel.html)\n    *   [Trámites y servicios](https://www.superdesalud.gob.cl/servicios/669/w3-channel.html)\n    *   [Registros](https://www.superdesalud.gob.cl/acreditacion/673/w3-channel.html)\n    *   [Participación Ciudadana](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6141.html)\n    *   [Biblioteca digital](https://www.superdesalud.gob.cl/documentacion/666/w3-channel.html)\n    *   [Observatorio de Calidad en Salud](https://www.superdesalud.gob.cl/observatorio/671/w3-channel.html)\n    *   [Extranet Fonasa, Isapres, FFAA y de Orden y Seguridad](https://www.superdesalud.gob.cl/servicios/669/w3-article-6038.html)\n*   [Contáctanos](https://www.superdesalud.gob.cl/664/w3-propertyvalue-794.html)\n*   [Facebook](https://www.facebook.com/Superintendencia-de-Salud-113210788736738/?ref=ts "Síganos en Facebook")\n*   [Facebook](https://twitter.com/SuperDeSalud)\n*   [Instagram](https://www.instagram.com/superdesaludchile/)\n*   [App Superintendencia de Salud para Adroid](https://play.google.com/store/apps/details?id=cl.dev.superintendecia_app)\n*   [Buscar](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3457.html#tr_buscador)\n    \n    Buscador general Buscar Botón de búsqueda\n    \n     buscar\n    \n\n[Inicio](https://www.superdesalud.gob.cl/664/w3-channel.html) / [Preguntas frecuentes](https://www.superdesalud.gob.cl/consultas/667/w3-channel.html) / [Materias FONASA](https://www.superdesalud.gob.cl/consultas/667/w3-propertyname-594.html) / [Afiliación y Desafiliación](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3457.html)\n\nAfiliación y Desafiliación\n==========================\n\nCompartiricono\n\n[![Image 1: Compartir en Facebook](https://www.superdesalud.gob.cl/consultas/667/channels-18_sociable_sprite_mask.gif)](http://www.facebook.com/share.php?u=http%3A%2F%2Fwww.supersalud.gob.cl%2Fconsultas%2F667%2Fw3-propertyvalue-3457.html&t=Afiliaci%C3%B3n%20y%20Desafiliaci%C3%B3n%20-%20Preguntas%20Frecuentes.%20Superintendenc ...

# %%
from pathlib import Path

# %%
import os 

current_directory = os.getcwd()
print(f"Current Directory: {current_directory}")
# Out:
# Current Directory: /Users/nicorod/Documents/repos/Chatbot-Fonasa/web_scraping

# %%
# Get the directory where the current script is located
script_dir = os.path.dirname(os.path.abspath(__file__))

# Assuming the script is in the src directory, we move up one level to get the project root
project_root = os.path.abspath(os.path.join(script_dir, os.pardir))

print(f"Project Root: {project_root}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Get the directory where the current script is located
# ----> 2 script_dir = os.path.dirname(os.path.abspath(__file__))
#       4 # Assuming the script is in the src directory, we move up one level to get the project root
#       5 project_root = os.path.abspath(os.path.join(script_dir, os.pardir))
#
# NameError: name '__file__' is not defined

# %%
def write_content_to_files(all_content: List[Dict[str, any]], output_dir: str, project_root: str):
    # Set the root directory of the project manually
    print(f"Manually Set Project Root Directory: {project_root}")
    
    # Ensure the output directory exists
    output_path = os.path.join(project_root, output_dir)
    os.makedirs(output_path, exist_ok=True)
    
    for site in all_content:
        provider = site.get('provider', '')
        for site_info in site.get('sites', []):
            name = site_info.get('name', '')
            content = site_info.get('content', '')
            
            # Create the content for the file
            file_content = f"Title: {provider}\n\n{content}"
            
            # Create a safe filename
            filename = f"{provider.replace(' ', '_')}_{name.replace(' ', '_')}.txt"
            file_path = os.path.join(output_path, filename)
            
            # Write the content to the file
            with open(file_path, 'w', encoding='utf-8') as f:
                f.write(file_content)
            print(f"Saved content to {file_path}")

# %%
all_content
# Out:
# [{'provider': 'Cobertura y Bonificaciones FONASA',
#   'sites': [{'name': 'Jina AI',
#     'content': 'Title: Cobertura y Bonificaciones\n\nURL Source: https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3459.html\n\nMarkdown Content:\n#### [¿A partir de cuándo los beneficiarios del Fonasa pueden comprar bonos?abrir cerrar](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3459.html#recuadros_articulo_5078_0 "Los afiliados de Fonasa y sus cargas pueden comprar bonos, una vez que cumplan con los requisitos de pago de cotizaciones según la calidad laboral o previsional del cotizante.")\n\nLos afiliados de Fonasa y sus cargas pueden comprar bonos, una vez que cumplan con los requisitos de pago de cotizaciones según la calidad laboral o previsional del cotizante.\n\nLos bonos de Fonasa permiten acceder a una consulta o procedimiento médico con un prestador que se encuentre en convenio, a través de libre elección.\n\nFonasa cuenta con cuatro tipos de bonos para que te atiendas con el profesional de la salud que necesites:\n\n**Bono electrónico:** puedes comprar este bono directamente en el prestador en convenio con Fonasa, a través del sistema Imed y/o Medipass con tu huella dactilar.\n\n**Bono web:** puedes comprar este bono de forma digital en "Mi Fonasa" para consultas de médicos en convenio. Recibirás un correo electrónico y un mensaje de texto con tu bono para que acudas directamente al prestador.\n\n**Prefolio:** es un código que generas en Mi Fonasa o en el call center, que te permite pagar el bono consulta en Sencillito o o Klap (ex Multicaja). Recibirás un voucher, que corresponde al bono, que debes presentar en el prestador el día de tu cita.\n\n**Bono papel:** puedes comprarlo en las sucursales de Fonasa, ChileAtiende y algunos hospitales, clínicas y municipalidades.\n\n#### [¿Cómo acceden los beneficiarios del Fonasa a las atenciones de salud?abrir cerrar](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3459.html#recuadros_articulo_5078_1 "Los beneficiarios del Fonasa acceden a las atenciones de salud a través de 2 (dos) modalidades de atención: Modalidad de Atención Institucional y Modalidad de Libre Elección. ")\n\nLos beneficiarios del Fonasa acceden a las atenciones de salud a través de 2 (dos) modalidades de atención: Modalidad de Atención Institucional y Modalidad de Libre Elección.\n\nEl valor que pagará un beneficiario del Fonasa por la atención otorgada, dependerá de la modalidad de atención que utilice.\n\n*   Si utiliza la **Modalidad de Atención Institucional**, el pago que deberá efectuar dependerá del grupo de ingreso en el cual se encuentre clasificado (grupos B, C o D). El valor de la atención en consultorios de atención primaria es gratuita.\n*   Si utiliza la **Modalidad de Libre Elección**, el valor de la atención dependerá del nivel de inscripción del profesional o institución de salud en convenio con Fonasa.\n\n#### [¿Cómo acceden los cotizantes y beneficiarios del Fonasa al Pago Asociado a Diagnóstico (PAD)?abrir cerrar](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3459.html#recuadros_articulo_5078_2 "El cotizante y beneficiarios del Fonasa acceden al beneficio PAD, a través de un convenio vigente con el Fondo Nacional de Salud (Fonasa) suscrito por los prestadores de salud que cumplen con los requisitos técnicos y de calidad para su realización.")\n\nEl cotizante y beneficiarios del Fonasa acceden al beneficio PAD, a través de un convenio vigente con el Fondo Nacional de Salud (Fonasa) suscrito por los prestadores de salud que cumplen con los requisitos técnicos y de calidad para su realización.\n\nEl PAD (Pago Asociado a Diagnóstico), es una forma de pago que le permite al cotizante y/o beneficiario del Fondo Nacional de Salud (Fonasa) conocer por anticipado el valor total de la cuenta en aquellas intervenciones quirúrgicas inscritas en los establecimientos de salud que tienen convenio con Fonasa.\n\nEl prestador, deberá informar de manera completa y detallada al cotizante y/o beneficiario acerca de las condiciones de la hosp ...
#  {'provider': 'Cotizaciones de Salud FONASA',
#   'sites': [{'name': 'Jina AI',
#     'content': 'Title: Cotizaciones de Salud\n\nURL Source: https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3458.html\n\nMarkdown Content:\nCotizaciones de Salud - Preguntas Frecuentes. Superintendencia de Salud, Gobierno de Chile.\n===============\n     [Contenido principal](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3458.html#contents)\n\nToggle navigation [Superintendencia de Salud - Gobierno de Chile](https://www.superdesalud.gob.cl/664/w3-channel.html "Logo oficial de la Superintendencia de Salud del Gobierno de Chile")\n\n*   [Inicio](https://www.superdesalud.gob.cl/664/w3-channel.html "Ir al inicio")\n*   [Atención Personas](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3458.html#)\n    *   [Beneficiarios Fonasa](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6058.html)\n    *   [Beneficiarios Isapres](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6059.html)\n*   [Atención Prestadores](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3458.html#)\n    *   [Entidades acreditadoras](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6056.html)\n    *   [Entidades certificadoras](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6057.html)\n    *   [Prestadores individuales](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6054.html)\n    *   [Prestadores institucionales](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6055.html)\n*   [Más de Supersalud](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3458.html#)\n    *   [Acerca de la Superintendencia](https://www.superdesalud.gob.cl/664/w3-propertyname-693.html)\n    *   [Regulación](https://www.superdesalud.gob.cl/normativa/668/w3-channel.html)\n    *   [Fiscalización](https://www.superdesalud.gob.cl/664/w3-propertyname-582.html)\n    *   [Sala de prensa](https://www.superdesalud.gob.cl/prensa/672/w3-channel.html)\n    *   [Orientación en salud](https://www.superdesalud.gob.cl/difusion/665/w3-channel.html)\n    *   [Trámites y servicios](https://www.superdesalud.gob.cl/servicios/669/w3-channel.html)\n    *   [Registros](https://www.superdesalud.gob.cl/acreditacion/673/w3-channel.html)\n    *   [Participación Ciudadana](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6141.html)\n    *   [Biblioteca digital](https://www.superdesalud.gob.cl/documentacion/666/w3-channel.html)\n    *   [Observatorio de Calidad en Salud](https://www.superdesalud.gob.cl/observatorio/671/w3-channel.html)\n    *   [Extranet Fonasa, Isapres, FFAA y de Orden y Seguridad](https://www.superdesalud.gob.cl/servicios/669/w3-article-6038.html)\n*   [Contáctanos](https://www.superdesalud.gob.cl/664/w3-propertyvalue-794.html)\n*   [Facebook](https://www.facebook.com/Superintendencia-de-Salud-113210788736738/?ref=ts "Síganos en Facebook")\n*   [Facebook](https://twitter.com/SuperDeSalud)\n*   [Instagram](https://www.instagram.com/superdesaludchile/)\n*   [App Superintendencia de Salud para Adroid](https://play.google.com/store/apps/details?id=cl.dev.superintendecia_app)\n*   [Buscar](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3458.html#tr_buscador)\n    \n    Buscador general Buscar Botón de búsqueda\n    \n     buscar\n    \n\n[Inicio](https://www.superdesalud.gob.cl/664/w3-channel.html) / [Preguntas frecuentes](https://www.superdesalud.gob.cl/consultas/667/w3-channel.html) / [Materias FONASA](https://www.superdesalud.gob.cl/consultas/667/w3-propertyname-594.html) / [Cotizaciones de Salud](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3458.html)\n\nCotizaciones de Salud\n=====================\n\nCompartiricono\n\n[![Image 1: Compartir en Facebook](https://www.superdesalud.gob.cl/consultas/667/channels-18_sociable_sprite_mask.gif)](http://www.facebook.com/share.php?u=http%3A%2F%2Fwww.supersalud.gob.cl%2Fconsultas%2F667%2Fw3-propertyvalue-3458.html&t=Cotizaciones%20de%20Salud%20-%20Preguntas%20Frecuentes.%20Superintendencia%20de%20Salud%2C%20Gobierno%20de%20Chi ...
#  {'provider': 'Afiliacion y desafiliacion FONASA',
#   'sites': [{'name': 'Jina AI',
#     'content': 'Title: Afiliación y Desafiliación\n\nURL Source: https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3457.html\n\nMarkdown Content:\nAfiliación y Desafiliación - Preguntas Frecuentes. Superintendencia de Salud, Gobierno de Chile.\n===============\n     [Contenido principal](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3457.html#contents)\n\nToggle navigation [Superintendencia de Salud - Gobierno de Chile](https://www.superdesalud.gob.cl/664/w3-channel.html "Logo oficial de la Superintendencia de Salud del Gobierno de Chile")\n\n*   [Inicio](https://www.superdesalud.gob.cl/664/w3-channel.html "Ir al inicio")\n*   [Atención Personas](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3457.html#)\n    *   [Beneficiarios Fonasa](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6058.html)\n    *   [Beneficiarios Isapres](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6059.html)\n*   [Atención Prestadores](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3457.html#)\n    *   [Entidades acreditadoras](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6056.html)\n    *   [Entidades certificadoras](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6057.html)\n    *   [Prestadores individuales](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6054.html)\n    *   [Prestadores institucionales](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6055.html)\n*   [Más de Supersalud](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3457.html#)\n    *   [Acerca de la Superintendencia](https://www.superdesalud.gob.cl/664/w3-propertyname-693.html)\n    *   [Regulación](https://www.superdesalud.gob.cl/normativa/668/w3-channel.html)\n    *   [Fiscalización](https://www.superdesalud.gob.cl/664/w3-propertyname-582.html)\n    *   [Sala de prensa](https://www.superdesalud.gob.cl/prensa/672/w3-channel.html)\n    *   [Orientación en salud](https://www.superdesalud.gob.cl/difusion/665/w3-channel.html)\n    *   [Trámites y servicios](https://www.superdesalud.gob.cl/servicios/669/w3-channel.html)\n    *   [Registros](https://www.superdesalud.gob.cl/acreditacion/673/w3-channel.html)\n    *   [Participación Ciudadana](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6141.html)\n    *   [Biblioteca digital](https://www.superdesalud.gob.cl/documentacion/666/w3-channel.html)\n    *   [Observatorio de Calidad en Salud](https://www.superdesalud.gob.cl/observatorio/671/w3-channel.html)\n    *   [Extranet Fonasa, Isapres, FFAA y de Orden y Seguridad](https://www.superdesalud.gob.cl/servicios/669/w3-article-6038.html)\n*   [Contáctanos](https://www.superdesalud.gob.cl/664/w3-propertyvalue-794.html)\n*   [Facebook](https://www.facebook.com/Superintendencia-de-Salud-113210788736738/?ref=ts "Síganos en Facebook")\n*   [Facebook](https://twitter.com/SuperDeSalud)\n*   [Instagram](https://www.instagram.com/superdesaludchile/)\n*   [App Superintendencia de Salud para Adroid](https://play.google.com/store/apps/details?id=cl.dev.superintendecia_app)\n*   [Buscar](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3457.html#tr_buscador)\n    \n    Buscador general Buscar Botón de búsqueda\n    \n     buscar\n    \n\n[Inicio](https://www.superdesalud.gob.cl/664/w3-channel.html) / [Preguntas frecuentes](https://www.superdesalud.gob.cl/consultas/667/w3-channel.html) / [Materias FONASA](https://www.superdesalud.gob.cl/consultas/667/w3-propertyname-594.html) / [Afiliación y Desafiliación](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3457.html)\n\nAfiliación y Desafiliación\n==========================\n\nCompartiricono\n\n[![Image 1: Compartir en Facebook](https://www.superdesalud.gob.cl/consultas/667/channels-18_sociable_sprite_mask.gif)](http://www.facebook.com/share.php?u=http%3A%2F%2Fwww.supersalud.gob.cl%2Fconsultas%2F667%2Fw3-propertyvalue-3457.html&t=Afiliaci%C3%B3n%20y%20Desafiliaci%C3%B3n%20-%20Preguntas%20Frecuentes.%20Superintendenc ...
#  {'provider': 'Seguro catastrófico',
#   'sites': [{'name': 'Jina AI',
#     'content': 'Title: Seguro catastrófico\n\nURL Source: https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-4010.html\n\nMarkdown Content:\nSeguro catastrófico - Preguntas Frecuentes. Superintendencia de Salud, Gobierno de Chile.\n===============\n     [Contenido principal](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-4010.html#contents)\n\nToggle navigation [Superintendencia de Salud - Gobierno de Chile](https://www.superdesalud.gob.cl/664/w3-channel.html "Logo oficial de la Superintendencia de Salud del Gobierno de Chile")\n\n*   [Inicio](https://www.superdesalud.gob.cl/664/w3-channel.html "Ir al inicio")\n*   [Atención Personas](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-4010.html#)\n    *   [Beneficiarios Fonasa](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6058.html)\n    *   [Beneficiarios Isapres](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6059.html)\n*   [Atención Prestadores](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-4010.html#)\n    *   [Entidades acreditadoras](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6056.html)\n    *   [Entidades certificadoras](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6057.html)\n    *   [Prestadores individuales](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6054.html)\n    *   [Prestadores institucionales](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6055.html)\n*   [Más de Supersalud](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-4010.html#)\n    *   [Acerca de la Superintendencia](https://www.superdesalud.gob.cl/664/w3-propertyname-693.html)\n    *   [Regulación](https://www.superdesalud.gob.cl/normativa/668/w3-channel.html)\n    *   [Fiscalización](https://www.superdesalud.gob.cl/664/w3-propertyname-582.html)\n    *   [Sala de prensa](https://www.superdesalud.gob.cl/prensa/672/w3-channel.html)\n    *   [Orientación en salud](https://www.superdesalud.gob.cl/difusion/665/w3-channel.html)\n    *   [Trámites y servicios](https://www.superdesalud.gob.cl/servicios/669/w3-channel.html)\n    *   [Registros](https://www.superdesalud.gob.cl/acreditacion/673/w3-channel.html)\n    *   [Participación Ciudadana](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6141.html)\n    *   [Biblioteca digital](https://www.superdesalud.gob.cl/documentacion/666/w3-channel.html)\n    *   [Observatorio de Calidad en Salud](https://www.superdesalud.gob.cl/observatorio/671/w3-channel.html)\n    *   [Extranet Fonasa, Isapres, FFAA y de Orden y Seguridad](https://www.superdesalud.gob.cl/servicios/669/w3-article-6038.html)\n*   [Contáctanos](https://www.superdesalud.gob.cl/664/w3-propertyvalue-794.html)\n*   [Facebook](https://www.facebook.com/Superintendencia-de-Salud-113210788736738/?ref=ts "Síganos en Facebook")\n*   [Facebook](https://twitter.com/SuperDeSalud)\n*   [Instagram](https://www.instagram.com/superdesaludchile/)\n*   [App Superintendencia de Salud para Adroid](https://play.google.com/store/apps/details?id=cl.dev.superintendecia_app)\n*   [Buscar](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-4010.html#tr_buscador)\n    \n    Buscador general Buscar Botón de búsqueda\n    \n     buscar\n    \n\n[Inicio](https://www.superdesalud.gob.cl/664/w3-channel.html) / [Preguntas frecuentes](https://www.superdesalud.gob.cl/consultas/667/w3-channel.html) /[Materias FONASA](https://www.superdesalud.gob.cl/consultas/667/w3-propertyname-594.html) / [Seguro catastrófico](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-4010.html)\n\nSeguro catastrófico\n===================\n\nCompartiricono\n\n[![Image 1: Compartir en Facebook](https://www.superdesalud.gob.cl/consultas/667/channels-18_sociable_sprite_mask.gif)](http://www.facebook.com/share.php?u=http%3A%2F%2Fwww.supersalud.gob.cl%2Fconsultas%2F667%2Fw3-propertyvalue-4010.html&t=Seguro%20catastr%C3%B3fico%20-%20Preguntas%20Frecuentes.%20Superintendencia%20de%20Salud%2C%20Gobierno%20de%20Chile. "Faceb ...
#  {'provider': 'Garantías explícitas en Salud GES',
#   'sites': [{'name': 'Jina AI',
#     'content': 'Title: Garantías explícitas en Salud GES\n\nURL Source: https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3460.html\n\nMarkdown Content:\nGarantías explícitas en Salud GES - Preguntas Frecuentes. Superintendencia de Salud, Gobierno de Chile.\n===============\n      [Contenido principal](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3460.html#contents)\n\nToggle navigation [Superintendencia de Salud - Gobierno de Chile](https://www.superdesalud.gob.cl/664/w3-channel.html "Logo oficial de la Superintendencia de Salud del Gobierno de Chile")\n\n*   [Inicio](https://www.superdesalud.gob.cl/664/w3-channel.html "Ir al inicio")\n*   [Atención Personas](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3460.html#)\n    *   [Beneficiarios Fonasa](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6058.html)\n    *   [Beneficiarios Isapres](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6059.html)\n*   [Atención Prestadores](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3460.html#)\n    *   [Entidades acreditadoras](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6056.html)\n    *   [Entidades certificadoras](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6057.html)\n    *   [Prestadores individuales](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6054.html)\n    *   [Prestadores institucionales](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6055.html)\n*   [Más de Supersalud](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3460.html#)\n    *   [Acerca de la Superintendencia](https://www.superdesalud.gob.cl/664/w3-propertyname-693.html)\n    *   [Regulación](https://www.superdesalud.gob.cl/normativa/668/w3-channel.html)\n    *   [Fiscalización](https://www.superdesalud.gob.cl/664/w3-propertyname-582.html)\n    *   [Sala de prensa](https://www.superdesalud.gob.cl/prensa/672/w3-channel.html)\n    *   [Orientación en salud](https://www.superdesalud.gob.cl/difusion/665/w3-channel.html)\n    *   [Trámites y servicios](https://www.superdesalud.gob.cl/servicios/669/w3-channel.html)\n    *   [Registros](https://www.superdesalud.gob.cl/acreditacion/673/w3-channel.html)\n    *   [Participación Ciudadana](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6141.html)\n    *   [Biblioteca digital](https://www.superdesalud.gob.cl/documentacion/666/w3-channel.html)\n    *   [Observatorio de Calidad en Salud](https://www.superdesalud.gob.cl/observatorio/674/w3-channel.html)\n    *   [Extranet Fonasa, Isapres, FFAA y de Orden y Seguridad](https://www.superdesalud.gob.cl/servicios/669/w3-article-6038.html)\n*   [Contáctanos](https://www.superdesalud.gob.cl/664/w3-propertyvalue-794.html)\n*   [Facebook](https://www.facebook.com/Superintendencia-de-Salud-113210788736738/?ref=ts "Síganos en Facebook")\n*   [Facebook](https://twitter.com/SuperDeSalud)\n*   [Instagram](https://www.instagram.com/superdesaludchile/)\n*   [App Superintendencia de Salud para Adroid](https://play.google.com/store/apps/details?id=cl.dev.superintendecia_app)\n*   [Buscar](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3460.html#tr_buscador)\n    \n    Buscador general Buscar Botón de búsqueda\n    \n     buscar\n    \n\n[Inicio](https://www.superdesalud.gob.cl/664/w3-channel.html) / [Preguntas frecuentes](https://www.superdesalud.gob.cl/consultas/667/w3-channel.html) /[Materias FONASA](https://www.superdesalud.gob.cl/consultas/667/w3-propertyname-594.html) / [Garantías explícitas en Salud GES](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3460.html)\n\nGarantías explícitas en Salud GES\n=================================\n\nCompartiricono\n\n[![Image 1: Compartir en Facebook](https://www.superdesalud.gob.cl/consultas/667/channels-18_sociable_sprite_mask.gif)](http://www.facebook.com/share.php?u=http%3A%2F%2Fwww.supersalud.gob.cl%2Fconsultas%2F667%2Fw3-propertyvalue-3460.html&t=Garant%C3%ADas%20expl%C3%ADcitas%20en%20Salud%20GES% ...
#  {'provider': 'Licencias Médicas y Subsidios por Incapacidad Laboral',
#   'sites': [{'name': 'Jina AI',
#     'content': 'Title: Licencias Médicas y Subsidios por Incapacidad Laboral\n\nURL Source: https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3461.html\n\nMarkdown Content:\nLicencias Médicas y Subsidios por Incapacidad Laboral - Preguntas Frecuentes. Superintendencia de Salud, Gobierno de Chile.\n===============\n     [Contenido principal](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3461.html#contents)\n\nToggle navigation [Superintendencia de Salud - Gobierno de Chile](https://www.superdesalud.gob.cl/664/w3-channel.html "Logo oficial de la Superintendencia de Salud del Gobierno de Chile")\n\n*   [Inicio](https://www.superdesalud.gob.cl/664/w3-channel.html "Ir al inicio")\n*   [Atención Personas](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3461.html#)\n    *   [Beneficiarios Fonasa](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6058.html)\n    *   [Beneficiarios Isapres](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6059.html)\n*   [Atención Prestadores](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3461.html#)\n    *   [Entidades acreditadoras](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6056.html)\n    *   [Entidades certificadoras](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6057.html)\n    *   [Prestadores individuales](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6054.html)\n    *   [Prestadores institucionales](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6055.html)\n*   [Más de Supersalud](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3461.html#)\n    *   [Acerca de la Superintendencia](https://www.superdesalud.gob.cl/664/w3-propertyname-693.html)\n    *   [Regulación](https://www.superdesalud.gob.cl/normativa/668/w3-channel.html)\n    *   [Fiscalización](https://www.superdesalud.gob.cl/664/w3-propertyname-582.html)\n    *   [Sala de prensa](https://www.superdesalud.gob.cl/prensa/672/w3-channel.html)\n    *   [Orientación en salud](https://www.superdesalud.gob.cl/difusion/665/w3-channel.html)\n    *   [Trámites y servicios](https://www.superdesalud.gob.cl/servicios/669/w3-channel.html)\n    *   [Registros](https://www.superdesalud.gob.cl/acreditacion/673/w3-channel.html)\n    *   [Participación Ciudadana](https://www.superdesalud.gob.cl/664/w3-propertyvalue-6141.html)\n    *   [Biblioteca digital](https://www.superdesalud.gob.cl/documentacion/666/w3-channel.html)\n    *   [Observatorio de Calidad en Salud](https://www.superdesalud.gob.cl/observatorio/671/w3-channel.html)\n    *   [Extranet Fonasa, Isapres, FFAA y de Orden y Seguridad](https://www.superdesalud.gob.cl/servicios/669/w3-article-6038.html)\n*   [Contáctanos](https://www.superdesalud.gob.cl/664/w3-propertyvalue-794.html)\n*   [Facebook](https://www.facebook.com/Superintendencia-de-Salud-113210788736738/?ref=ts "Síganos en Facebook")\n*   [Facebook](https://twitter.com/SuperDeSalud)\n*   [Instagram](https://www.instagram.com/superdesaludchile/)\n*   [App Superintendencia de Salud para Adroid](https://play.google.com/store/apps/details?id=cl.dev.superintendecia_app)\n*   [Buscar](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3461.html#tr_buscador)\n    \n    Buscador general Buscar Botón de búsqueda\n    \n     buscar\n    \n\n[Inicio](https://www.superdesalud.gob.cl/664/w3-channel.html) / [Preguntas frecuentes](https://www.superdesalud.gob.cl/consultas/667/w3-channel.html) /[Materias FONASA](https://www.superdesalud.gob.cl/consultas/667/w3-propertyname-594.html) / [Licencias Médicas y Subsidios por Incapacidad Laboral](https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-3461.html)\n\nLicencias Médicas y Subsidios por Incapacidad Laboral\n=====================================================\n\nCompartiricono\n\n[![Image 1: Compartir en Facebook](https://www.superdesalud.gob.cl/consultas/667/channels-18_sociable_sprite_mask.gif)](http://www.facebook.com/share.php?u=http%3A%2F%2Fwww.supersalud.gob.cl%2F ...
#  {'provider': 'Ley Ricarte Soto',
#   'sites': [{'name': 'Jina AI',
#     'content': 'Title: Ley Ricarte Soto\n\nURL Source: https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-7142.html\n\nMarkdown Content:\n#### [¿Qué es la Ley Ricarte Soto (20.850)?](https://www.superdesalud.gob.cl/consultas/667/w3-article-18166.html "La Ley Nº 20.850 creó un Sistema de Protección Financiera para Diagnósticos y Tratamientos de Alto Costo, de carácter universal, que es asegurado por el FONASA a todos los beneficiarios de los sistemas previsionales de salud de Chile. Esto es, isapres, Fonasa y las Instituciones de Salud Previsional de las Fuerzas Armadas y de Orden y de Seguridad Pública. \xa0\xa0")\n\nLa Ley Nº 20.850 creó un Sistema de Protección Financiera para Diagnósticos y Tratamientos de Alto Costo, de carácter universal, que es asegurado por el FONASA a todos los beneficiarios de los sistemas previsionales de salud de Chile. Esto es, isapres, Fonasa y las Instituciones de Salud Previsional de las Fuerzas Armadas y de Orden y de Seguridad Pública.\n\n#### [¿Qué cubre el Sistema de Protección Financiera en el contexto de la Ley Ricarte Soto?](https://www.superdesalud.gob.cl/consultas/667/w3-article-18167.html "Cubre el 100% del valor de los medicamentos, dispositivos médicos o alimentos de alto costo, que se encuentran expresamente garantizados para cada problema de salud definido, según el decreto que los fija. Para algunos de estos problemas de salud, también garantiza la cobertura del examen de confirmación diagnóstica definido, exámenes específicos que, siendo también de alto costo, le permitirán verificar si posee el problema de salud.")\n\nCubre el 100% del valor de los medicamentos, dispositivos médicos o alimentos de alto costo, que se encuentran expresamente garantizados para cada problema de salud definido, según el decreto que los fija. Para algunos de estos problemas de salud, también garantiza la cobertura del examen de confirmación diagnóstica definido, exámenes específicos que, siendo también de alto costo, le permitirán verificar si posee el problema de salud.\n\n#### [¿Cómo accedo a los beneficios del Sistema de Protección Financiera?](https://www.superdesalud.gob.cl/consultas/667/w3-article-18168.html "El médico especialista tratante debe estar inscrito en el Sistema informático de la ley Ricarte Soto para efectuar la postulación del beneficiario, mediante la obtención de una clave habilitante en la página web del Fonasa. ")\n\nEl médico especialista tratante debe estar inscrito en el Sistema informático de la ley Ricarte Soto para efectuar la postulación del beneficiario, mediante la obtención de una clave habilitante en la página web del Fonasa.\n\nEl médico especialista que cuenta con la sospecha fundada de que el beneficiario tiene un diagnóstico o requiere un tratamiento de alto costo garantizado por esta ley, efectuará la postulación del beneficiario a este Sistema de Protección Financiera en la plataforma web del Fonasa.\n\nLos criterios de inclusión para los beneficiarios están definidos en los [Protocolos dictados por el Ministerio de Salud.](https://www.superdesalud.gob.cl/difusion/665/w3-propertyvalue-6088.html)\n\nPara cada problema de salud se define si la evaluación para la incorporación al Sistema corresponderá a la confirmación diagnóstica por el establecimiento que entrega el examen requerido o a la aprobación por el comité de expertos clínicos, según se trate.\n\n#### [¿Cuál será la Red de Prestadores que otorgará las prestaciones?](https://www.superdesalud.gob.cl/consultas/667/w3-article-18170.html "Su medico tratante le informará el prestador (establecimiento) que otorgará las prestaciones (los beneficios). Estos prestadores, públicos o privados, estarán previamente autorizados por el Ministerio de Salud para este Sistema de Protección Financiera.")\n\nSu medico tratante le informará el prestador (establecimiento) que otorgará las prestaciones (los beneficios). Estos prestadores, públicos o privados, estarán previamente autorizados por el Ministerio de Salu ...
#  {'provider': 'Beneficiarios Fonasa',
#   'sites': [{'name': 'Jina AI',
#     'content': 'Title: Beneficiarios Fonasa\n\nURL Source: https://www.superdesalud.gob.cl/consultas/667/w3-propertyvalue-6058.html\n\nMarkdown Content:\n#### [¿En qué consiste la ley N°20.394 sobre prohibición del cheque en garantía, cuándo fue promulgada y cuáles son sus alcances?](https://www.superdesalud.gob.cl/consultas/667/w3-article-6855.html "La ley N°20.394, prohíbe condicionar las atenciones médicas a un cheque o dinero en garantía. La referida ley fue promulgada con fecha 3 de noviembre de 2009, su publicación en el diario oficial e inicio de su vigencia fue el día 20 de noviembre de 2009. ")\n\nLa ley N°20.394, prohíbe condicionar las atenciones médicas a un cheque o dinero en garantía. La referida ley fue promulgada con fecha 3 de noviembre de 2009, su publicación en el diario oficial e inicio de su vigencia fue el día 20 de noviembre de 2009.\n\nAlcances de la Ley:\n\n*   La atención médica no puede ser condicionada a un cheque en garantía, sean atenciones de urgencia vital o programada. La ley autoriza a los pacientes a garantizar el pago de tales prestaciones y consultas, mediante el uso de letras de cambio, tarjetas de crédito, pagarés y carta de respaldo del empleador.\n*   El paciente que llega a un servicio de urgencia en situación de riesgo vital debe ser atendido inmediatamente, su atención no puede ser supeditada de modo alguno a la exigencia de un cheque, de dinero o cualquier otro medio de pago por esas prestaciones. La ley prohíbe y sanciona al servicio médico que no atiende a un paciente en riesgo vital. Lo mismo ocurre en caso de prestaciones programadas, la diferencia está que en este caso sí podrían solicitar la firma de un pagaré.\n*   El prestador que niega o restringe una atención de urgencia vital a la entrega de un cheque en garantía o dinero en efectivo, está actuando en contra de la ley y este hecho puede ocasionarle importantes sanciones. En ese caso el paciente o quien lo represente, tiene la posibilidad de ingresar un reclamo ante la Superintendencia de Salud.\n\n#### [¿Qué debe hacer un paciente si el prestador insiste en exigir el cheque en garantía?](https://www.superdesalud.gob.cl/consultas/667/w3-article-6861.html "El paciente, o quien lo represente, debe reunir los antecedentes que acrediten la exigencia, tales como: instructivo, copia del recibo de pago o boleta. Posteriormente, podrá reclamar ante la Superintendencia de Salud, por internet, oficina de Atención de Público de Santiago y Agencias Regionales.")\n\nEl paciente, o quien lo represente, debe reunir los antecedentes que acrediten la exigencia, tales como: instructivo, copia del recibo de pago o boleta. Posteriormente, podrá reclamar ante la Superintendencia de Salud, por internet, oficina de Atención de Público de Santiago y Agencias Regionales.\n\n*   Por internet en [www.supersalud.gob.cl](https://www.superdesalud.gob.cl/568/w3-channel.html), opción: [Formulario de reclamo por infracciones a la ley que prohíbe el cheque en garantía.](https://www.superdesalud.gob.cl/servicios/669/w3-article-6039.html)\n*   Oficina de Atención de Público de Santiago, ubicada en Alameda 1449, Torre 2, Local 12, Metro La Moneda.\n*   [Agencias Regionales](https://www.superdesalud.gob.cl/portal/w3-propertyvalue-6116.html).\n\nEl Formulario de reclamo deberá indicar todos los antecedentes necesarios para realizar una fiscalización tendiente a recuperar el cheque o dinero dejado en garantía y abrir un proceso sumarial y sancionatorio al prestador de salud.\n\n#### [¿La Ley de Cheque en Garantía exime a un paciente de la obligación de pagar las atenciones de salud que se le efectúen como consecuencia de una urgencia vital?](https://www.superdesalud.gob.cl/consultas/667/w3-article-6865.html "No, la Ley de Cheque en Garantía no exime a un paciente de la obligación de pagar las atenciones de salud producto de una urgencia vital. ")\n\nNo, la Ley de Cheque en Garantía no exime a un paciente de la obligación de pagar las atenciones de salud producto ...

# %%
output_directory = "data/raw"
project_root = "/Users/nicorod/Documents/repos/Chatbot-Fonasa/"
write_content_to_files(all_content, output_directory, project_root)
# Out:
# Manually Set Project Root Directory: /Users/nicorod/Documents/repos/Chatbot-Fonasa/
# Saved content to /Users/nicorod/Documents/repos/Chatbot-Fonasa/data/raw/Cobertura_y_Bonificaciones_FONASA_Jina_AI.txt
# Saved content to /Users/nicorod/Documents/repos/Chatbot-Fonasa/data/raw/Cotizaciones_de_Salud_FONASA_Jina_AI.txt
# Saved content to /Users/nicorod/Documents/repos/Chatbot-Fonasa/data/raw/Afiliacion_y_desafiliacion_FONASA_Jina_AI.txt
# Saved content to /Users/nicorod/Documents/repos/Chatbot-Fonasa/data/raw/Seguro_catastrófico_Jina_AI.txt
# Saved content to /Users/nicorod/Documents/repos/Chatbot-Fonasa/data/raw/Garantías_explícitas_en_Salud_GES_Jina_AI.txt
# Saved content to /Users/nicorod/Documents/repos/Chatbot-Fonasa/data/raw/Licencias_Médicas_y_Subsidios_por_Incapacidad_Laboral_Jina_AI.txt
# Saved content to /Users/nicorod/Documents/repos/Chatbot-Fonasa/data/raw/Ley_Ricarte_Soto_Jina_AI.txt
# Saved content to /Users/nicorod/Documents/repos/Chatbot-Fonasa/data/raw/Beneficiarios_Fonasa_Jina_AI.txt

# %% [markdown]
# ## Now let's use OpenAI and extract just the information we need
#
# Let's see how accurate the extraction task is between each provider.

# %% [markdown]
# First, we create an extraction function using OpenAI's gpt-4o to get only the pricing content from each scraped website from each provider.

# %%
pip install openai --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import getpass
from openai import OpenAI

OPENAI_API_KEY = getpass.getpass('Enter your OpenAI API key: ')

client = OpenAI(api_key=OPENAI_API_KEY)

def extract(user_input: str):
  entity_extraction_system_message = {"role": "system", "content": "Get me the three pricing tiers from this website's content, and return as a JSON with three keys: {cheapest: {name: str, price: float}, middle: {name: str, price: float}, most_expensive: {name: str, price: float}}"}

  messages = [entity_extraction_system_message]
  messages.append({"role": "user", "content": user_input})

  response = client.chat.completions.create(
        model="gpt-4o",
        messages=messages,
        stream=False,
        response_format={"type": "json_object"}
    )

  return response.choices[0].message.content
# Out:
# Enter your OpenAI API key: ··········

# %% [markdown]
# ### Then, we create a utility function to display that content in a table.

# %%
def display_extracted_content(results: List[Dict[str, any]], num_objects: int):
    table = PrettyTable()
    table.field_names = ["Site", "Provider Name", "Extracted Content"]

    # Ensure num_objects does not exceed the length of the results list
    num_objects = min(num_objects, len(results))

    # Process the specified number of items from the results list with a progress bar
    for result in tqdm(results[:num_objects], desc="Processing results"):
        provider_name = result["provider"]

        for site in result["sites"]:
            function_name = site["name"]
            content = site["content"]

            # Progress bar for each function
            for _ in tqdm(range(1), desc=f"Extracting content with {provider_name} for {function_name}"):
                extracted_content = extract(content)
                table.add_row([provider_name, function_name, extracted_content])

    table.max_width = 50  # Set the maximum width for better display
    table.hrules = ALL

    print("Extracted Content Table:")
    print(table)

# %%
display_extracted_content(all_content, num_objects=9)
# Out:
# Processing results:   0%|          | 0/4 [00:00<?, ?it/s]
# Extracting content with Articulate 360 by Adobe for Beautiful Soup:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Articulate 360 by Adobe for Beautiful Soup: 100%|██████████| 1/1 [00:01<00:00,  1.42s/it]
#
# Extracting content with Articulate 360 by Adobe for Firecrawl:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Articulate 360 by Adobe for Firecrawl: 100%|██████████| 1/1 [00:01<00:00,  1.72s/it]
#
# Extracting content with Articulate 360 by Adobe for Jina AI:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Articulate 360 by Adobe for Jina AI: 100%|██████████| 1/1 [00:01<00:00,  1.55s/it]
# Processing results:  25%|██▌       | 1/4 [00:04<00:14,  4.72s/it]
# Extracting content with 7taps for Beautiful Soup:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with 7taps for Beautiful Soup: 100%|██████████| 1/1 [00:02<00:00,  2.44s/it]
#
# Extracting content with 7taps for Firecrawl:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with 7taps for Firecrawl: 100%|██████████| 1/1 [00:01<00:00,  1.27s/it]
#
# Extracting content with 7taps for Jina AI:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with 7taps for Jina AI: 100%|██████████| 1/1 [00:01<00:00,  1.29s/it]
# Processing results:  50%|█████     | 2/4 [00:09<00:09,  4.90s/it]
# Extracting content with Mindsmith AI for Beautiful Soup:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Mindsmith AI for Beautiful Soup: 100%|██████████| 1/1 [00:41<00:00, 41.91s/it]
#
# Extracting content with Mindsmith AI for Firecrawl:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Mindsmith AI for Firecrawl: 100%|██████████| 1/1 [00:06<00:00,  6.14s/it]
#
# Extracting content with Mindsmith AI for Jina AI:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Mindsmith AI for Jina AI: 100%|██████████| 1/1 [00:05<00:00,  5.59s/it]
# Processing results:  75%|███████▌  | 3/4 [01:03<00:27, 27.17s/it]
# Extracting content with Cards-microlearning for Beautiful Soup:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Cards-microlearning for Beautiful Soup: 100%|██████████| 1/1 [00:46<00:00, 46.06s/it]
#
# Extracting content with Cards-microlearning for Firecrawl:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Cards-microlearning for Firecrawl: 100%|██████████| 1/1 [00:09<00:00,  9.29s/it]
#
# Extracting content with Cards-microlearning for Jina AI:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Cards-microlearning for Jina AI: 100%|██████████| 1/1 [00:01<00:00,  1.66s/it]
# Processing results: 100%|██████████| 4/4 [02:00<00:00, 30.12s/it]
# Extracted Content Table:
# +-------------------------+----------------+----------------------------------------------------+
# |           Site          | Provider Name  |                 Extracted Content                  |
# +-------------------------+----------------+----------------------------------------------------+
# | Articulate 360 by Adobe | Beautiful Soup |                         {                          |
# |                         |                |                    "cheapest": {                   |
# |                         |                |                      "name": "",                   |
# |                         |                |                      "price": 0.0                  |
# |                         |                |                          },                        |
# |                         |                |                     "middle": {                    |
# |                         |                |                      "name": "",                   |
# |                         |                |                      "price": 0.0                  |
# |                         |                |                          },                        |
# |                         |                |                 "most_expensive": {                |
# |                         |                |                      "name": "",                   |
# |                         |                |                      "price": 0.0                  |
# |                         |                |                          }                         |
# |                         |                |                         }                          |
# +-------------------------+----------------+----------------------------------------------------+
# | Articulate 360 by Adobe |   Firecrawl    |                         {                          |
# |                         |                |                    "cheapest": {                   |
# |                         |                |                "name": "Personal Plan",            |
# |                         |                |                    "price": 1099.0                 |
# |                         |                |                          },                        |
# |                         |                |                     "middle": {                    |
# |                         |                |                 "name": "Teams Plan",              |
# |                         |                |                    "price": 1399.0                 |
# |                         |                |                          },                        |
# |                         |                |                 "most_expensive": {                |
# |                         |                |                "name": "Reach 360 Pro",            |
# |                         |                |          "price": "Contact sales for pricing"      |
# |                         |                |                          }                         |
# |                         |                |                         }                          |
# +-------------------------+----------------+----------------------------------------------------+
# | Articulate 360 by Adobe |    Jina AI     |                         {                          |
# |                         |                |                    "cheapest": {                   |
# |                         |                |                "name": "Personal Plan",            |
# |                         |                |                    "price": 1099.0                 |
# |                         |                |                          },                        |
# |                         |                |                     "middle": {                    |
# |                         |                |                 "name": "Teams Plan",              |
# |                         |                |                    "price": 1399.0                 |
# |                         |                |                          },                        |
# |                         |                |                 "most_expensive": {                |
# |                         |                |             "name": "Reach 360 Pro Plan",          |
# |                         |                |                  "price": "Variable"               |
# |                         |                |                          }                         |
# |                         |                |                         }                          |
# +-------------------------+----------------+----------------------------------------------------+
# |          7taps          | Beautiful Soup |                         {                          |
# |                         |                |                    "cheapest": {                   |
# |                         |                |                    "name": "Free",                 |
# |                         |                |                      "price": 0.0                  |
# |                         |                |                          },                        |
# |                         |                |                     "middle": {                    |
# |                         |                |                     "name": "Pro",                 |
# |                         |                |                     "price": 99.0                  |
# |                         |                |                          },                        |
# |                         |                |                 "most_expensive": {                |
# |                         |                |                 "name": "Enterprise",              |
# |                         |                |                              "price": 0.0 	}                           |
# |                         |                |                         }                          |
# +-------------------------+----------------+----------------------------------------------------+
# |          7taps          |   Firecrawl    |                         {                          |
# |                         |                |                    "cheapest": {                   |
# |                         |                |                    "name": "Free",                 |
# |                         |                |                      "price": 0.0                  |
# |                         |                |                          },                        |
# |                         |                |                     "middle": {                    |
# |                         |                |                   "name": "Starter",               |
# |                         |                |                     "price": 20.0                  |
# |                         |                |                          },                        |
# |                         |                |                 "most_expensive": {                |
# |                         |                |                     "name": "Pro",                 |
# |                         |                |                     "price": 99.0                  |
# |                         |                |                          }                         |
# |                         |                |                         }                          |
# +-------------------------+----------------+----------------------------------------------------+
# |          7taps          |    Jina AI     |                         {                          |
# |                         |                |                    "cheapest": {                   |
# |                         |                |                    "name": "Free",                 |
# |                         |                |                     "price": 0.00                  |
# |                         |                |                          },                        |
# |                         |                |                     "middle": {                    |
# |                         |                |                     "name": "Pro",                 |
# |                         |                |                    "price": 199.00                 |
# |                         |                |                          },                        |
# |                         |                |                 "most_expensive": {                |
# |                         |                |                 "name": "Enterprise",              |
# |                         |                |                    "price": 499.00                 |
# |                         |                |                          }                         |
# |                         |                |                         }                          |
# +-------------------------+----------------+----------------------------------------------------+
# |       Mindsmith AI      | Beautiful Soup |                         {                          |
# |                         |                |                    "cheapest": {                   |
# |                         |                |                    "name": "Free",                 |
# |                         |                |                      "price": 0.0                  |
# |                         |                |                          },                        |
# |                         |                |                     "middle": {                    |
# |                         |                |                "name": "Professional",             |
# |                         |                |                     "price": 39.0                  |
# |                         |                |                          },                        |
# |                         |                |                 "most_expensive": {                |
# |                         |                |                    "name": "Team",                 |
# |                         |                |                     "price": null                  |
# |                         |                |                          }                         |
# |                         |                |                         }                          |
# +-------------------------+----------------+----------------------------------------------------+
# |       Mindsmith AI      |   Firecrawl    |                         {                          |
# |                         |                |                    "cheapest": {                   |
# |                         |                |                    "name": "Free",                 |
# |                         |                |                      "price": 0.0                  |
# |                         |                |                          },                        |
# |                         |                |                     "middle": {                    |
# |                         |                |                "name": "Professional",             |
# |                         |                |                     "price": 31.20                 |
# |                         |                |                          },                        |
# |                         |                |                 "most_expensive": {                |
# |                         |                |                    "name": "Team",                 |
# |                         |                |                     "price": 39.0                  |
# |                         |                |                          }                         |
# |                         |                |                         }                          |
# +-------------------------+----------------+----------------------------------------------------+
# |       Mindsmith AI      |    Jina AI     |                         {                          |
# |                         |                |                    "cheapest": {                   |
# |                         |                |                    "name": "Free",                 |
# |                         |                |                      "price": 0.0                  |
# |                         |                |                          },                        |
# |                         |                |                     "middle": {                    |
# |                         |                |                "name": "Professional",             |
# |                         |                |                     "price": 31.2                  |
# |                         |                |                          },                        |
# |                         |                |                 "most_expensive": {                |
# |                         |                |                    "name": "Team",                 |
# |                         |                |                     "price": 39.0                  |
# |                         |                |                          }                         |
# |                         |                |                         }                          |
# +-------------------------+----------------+----------------------------------------------------+
# |   Cards-microlearning   | Beautiful Soup |                         {                          |
# |                         |                |                    "cheapest": {                   |
# |                         |                |                    "name": "Basic",                |
# |                         |                |                     "price": 99.0                  |
# |                         |                |                          },                        |
# |                         |                |                     "middle": {                    |
# |                         |                |                   "name": "Starter",               |
# |                         |                |                    "price": 4400.0                 |
# |                         |                |                          },                        |
# |                         |                |                 "most_expensive": {                |
# |                         |                |                  "name": "Business",               |
# |                         |                |                    "price": 10500.0                |
# |                         |                |                          }                         |
# |                         |                |                         }                          |
# +-------------------------+----------------+----------------------------------------------------+
# |   Cards-microlearning   |   Firecrawl    |                         {                          |
# |                         |                |                    "cheapest": {                   |
# |                         |                |                 "name": "BASIC OFFER",             |
# |                         |                |                     "price": 99.0                  |
# |                         |                |                          },                        |
# |                         |                |                     "middle": {                    |
# |                         |                |                   "name": "Starter",               |
# |                         |                |                    "price": 4400.0                 |
# |                         |                |                          },                        |
# |                         |                |                 "most_expensive": {                |
# |                         |                |                  "name": "Business",               |
# |                         |                |                    "price": 10500.0                |
# |                         |                |                          }                         |
# |                         |                |                         }                          |
# +-------------------------+----------------+----------------------------------------------------+
# |   Cards-microlearning   |    Jina AI     |                         {                          |
# |                         |                |                    "cheapest": {                   |
# |                         |                |         "name": "HT cost/ additional license",     |
# |                         |                |                      "price": 3.6                  |
# |                         |                |                          },                        |
# |                         |                |                     "middle": {                    |
# |                         |                |        "name": "Getting Started Webinar Ickoff     |
# |                         |                | Meeting + 1 Workshop (1h) for annual commitments", |
# |                         |                |                     "price": 89.0                  |
# |                         |                |                          },                        |
# |                         |                |                 "most_expensive": {                |
# |                         |                |     "name": "Getting Started Webinar + 4 Workshops |
# |                         |                |           (1h) for annual commitments",            |
# |                         |                |                     "price": null                  |
# |                         |                |                          }                         |
# |                         |                |                         }                          |
# |                         |                |                                                    |
# |                         |                |                                                    |
# +-------------------------+----------------+----------------------------------------------------+

# %% [markdown]
# ## Bonus: Scrapegraph-ai

# %% [markdown]
# ### Scrapegraph-ai
#
# Scrapegraph-ai takes care of the entire flow (from scrape to extraction). It's also interesting that it's node-based, and can run off of local models (Ollama supported). But I couldn't find a way to get cost estimates based on tokens used.
#
# Demo link: https://scrapegraph-ai-demo.streamlit.app/
